# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

train_df = pd.read_csv('/Users/matildacotton/Desktop/semester 2 2024/topics/hctsa-catch22-features-training.csv')
test_df = pd.read_csv('/Users/matildacotton/Desktop/semester 2 2024/topics/hctsa-catch22-features-testing.csv')

X_train = train_df.drop('Sinus Bradycardia', axis=1).values
y_train = train_df['Sinus Bradycardia'].values  

X_test = test_df.drop('Normal', axis=1).values  
y_test = test_df['Normal'].values 

clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8468
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
#           1 degree atrioventricular block       1.00      0.81      0.90        75
#           2 degree atrioventricular block       1.00      0.73      0.85        15
# 2 degree atrioventricular block(Type one)       1.00      1.00      1.00         3
#           3 degree atrioventricular block       1.00      1.00      1.00         1
#                       Atrial Fibrillation       0.99      0.75      0.85        88
#                            Atrial Flutter       0.97      0.79      0.87       527
#                        Atrial Tachycardia       1.00      0.67      0.80         9
#    Atrioventricular Reentrant Tachycardia       1.00      1.00      1.00         1
#                           Axis left shift       1.00      0.83      0.91       165
#                          Axis right shift       1.00      0.73      0.84        44
#    Early repolarization of the ventricles       1.00      0.80      0.89        61
#                    Intraventricular block       1.00      0.77      0.87        22
#    Myocardial infraction in the side wall       1.00      1.00      1.00         3
#                                    Normal       0.77      0.89      0.83      1996
#                             P wave Change       1.00      0.69      0.82        13
#                     PR interval extension       1.00      1.00      1.00         1
#                     QT interval extension       1.00      0.63      0.77        27
#                              ST drop down       1.00      0.83      0.90        23
#                              ST extension       1.00      0.88      0.94        17
#                                ST tilt up       1.00      0.67      0.80        21
#                               ST-T Change       0.99      0.74      0.85       152
#   Sinus Atrium to Atrial Wandering Rhythm       0.00      0.00      0.00         2
#                         Sinus Bradycardia       0.78      0.92      0.85      1800
#                        Sinus Irregularity       0.95      0.79      0.86       461
#                              Sinus Rhythm       0.85      0.84      0.85      1184
#                         Sinus Tachycardia       0.82      0.86      0.84       780
#              Supraventricular Tachycardia       1.00      0.74      0.85        73
#                             T wave Change       0.99      0.76      0.86       723
#                           T wave opposite       1.00      0.78      0.87       283
#                                    U wave       1.00      0.57      0.73         7
#                                       WPW       1.00      0.70      0.82        10
#                           abnormal Q wave       1.00      0.78      0.88        82
#                    atrial premature beats       1.00      0.78      0.88        36
#                    atrioventricular block       1.00      0.60      0.75        10
#                       colockwise rotation       1.00      1.00      1.00         6
#                countercolockwise rotation       0.92      0.92      0.92        13
#                    junctional escape beat       1.00      1.00      1.00         2
#                 junctional premature beat       1.00      1.00      1.00         2
#            left front bundle branch block       1.00      0.86      0.93        22
#                left ventricle hypertrophy       1.00      0.57      0.73        14
#             lower voltage QRS in all lead       1.00      0.72      0.84       115
#                  right atrial hypertrophy       1.00      0.50      0.67         2
#                 right bundle branch block       1.00      0.81      0.90        74
#               right ventricle hypertrophy       1.00      1.00      1.00         1
#                   ventricular escape beat       1.00      1.00      1.00         1
#                   ventricular fusion wave       1.00      0.67      0.80         3
#                 ventricular preexcitation       1.00      1.00      1.00         2
#                ventricular premature beat       1.00      0.70      0.82        57
#
#                                  accuracy                           0.85      9029
#                                 macro avg       0.96      0.79      0.86      9029
#                              weighted avg       0.86      0.85      0.85      9029
#
#
# Confusion Matrix:
# [[61  0  0 ...  0  0  0]
#  [ 0 11  0 ...  0  0  0]
#  [ 0  0  3 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  2  0  0]
#  [ 0  0  0 ...  0  2  0]
#  [ 0  0  0 ...  0  0 40]]
# /Users/matildacotton/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/matildacotton/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/matildacotton/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
